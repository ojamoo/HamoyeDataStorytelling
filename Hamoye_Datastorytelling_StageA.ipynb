# %% [markdown]
# <a href="https://colab.research.google.com/github/ojamoo/HamoyeDataStorytelling/blob/main/Hamoye_Datastorytelling_StageA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = "latin-1")
print(df)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'

# %%
df_2017=df['Y2017']

# %%
df_2017
# Out:
# 0        41389.00
# 1            0.00
# 2         3341.00
# 3           92.82
# 4           80.19
#            ...
# 60938       19.00
# 60939        1.33
# 60940        1.00
# 60941        0.04
# 60942        0.02
# Name: Y2017, Length: 60943, dtype: float64

# %%
df.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df_2017.mean().round(2)
# Out:
# 140.92

# %%
df_2017.describe().round(2)
# Out:
# count     59437.00
# mean        140.92
# std        1671.86
# min       -1582.00
# 25%           0.00
# 50%           0.10
# 75%           9.00
# max      190873.00
# Name: Y2017, dtype: float64

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.groupby('Area')['Area'].count()
# Out:
# Area
# Algeria                        1313
# Angola                         1424
# Benin                          1285
# Botswana                       1378
# Burkina Faso                   1409
# Cabo Verde                     1260
# Cameroon                       1460
# Central African Republic       1344
# Chad                           1343
# Comoros                          45
# Congo                          1413
# Côte d'Ivoire                  1467
# Djibouti                       1095
# Egypt                          1488
# Eswatini                       1284
# Ethiopia                       1447
# Ethiopia PDR                     39
# Gabon                          1245
# Gambia                         1168
# Ghana                          1354
# Guinea                         1410
# Guinea-Bissau                  1128
# Kenya                          1560
# Lesotho                        1150
# Liberia                        1206
# Madagascar                     1439
# ...

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.dtypes
# Out:
# Area Code         int64
# Area             object
# Item Code         int64
# Item             object
# Element Code      int64
# Element          object
# Unit             object
# Y2014           float64
# Y2015           float64
# Y2016           float64
# Y2017           float64
# Y2018           float64
# dtype: object

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df.groupby('Element')['Element'].count()
# Out:
# Element
# Domestic supply quantity                  5295
# Export Quantity                           4403
# Fat supply quantity (g/capita/day)        5023
# Feed                                      1319
# Food                                      4941
# Food supply (kcal/capita/day)             5014
# Food supply quantity (kg/capita/yr)       4905
# Import Quantity                           5139
# Losses                                    2009
# Other uses (non-food)                     1732
# Processing                                2010
# Production                                3881
# Protein supply quantity (g/capita/day)    5023
# Residuals                                 4655
# Seed                                       762
# Stock Variation                           4232
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Element, dtype: int64

# %%
df.groupby('Element').sum().loc[['Protein supply quantity (g/capita/day)'],['Y2015']]
# Out:
#                                            Y2015
# Element
# Protein supply quantity (g/capita/day)  11833.95

# %%
df.groupby(['Element','Area']).sum().loc[['Protein supply quantity (g/capita/day)'],['Y2015']]
# Out:
#                                                                      Y2015
# Element                                Area
# Protein supply quantity (g/capita/day) Algeria                      377.37
#                                        Angola                       214.15
#                                        Benin                        271.97
#                                        Botswana                     278.52
#                                        Burkina Faso                 317.99
#                                        Cabo Verde                   278.41
#                                        Cameroon                     291.53
#                                        Central African Republic     173.70
#                                        Chad                         252.28
#                                        Congo                        227.08
#                                        Côte d'Ivoire                232.59
# ...

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
Ist = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

# %%
pd.DataFrame(Ist, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
df.groupby('Item')['Item'].count()
# Out:
# Item
# Alcohol, Non-Food      283
# Alcoholic Beverages    564
# Animal Products        135
# Animal fats            639
# Apples and products    517
#                       ...
# Vegetables, Other      583
# Vegetal Products       135
# Wheat and products     653
# Wine                   497
# Yams                   383
# Name: Item, Length: 119, dtype: int64

# %%
df.groupby('Item').sum().loc[['Wine']]
# Out:
#       Area Code  Item Code  Element Code    Y2014    Y2015    Y2016    Y2017  \
# Item
# Wine      66206    1319535       1818328  4497.36  4251.81  3872.09  4178.02
#
#         Y2018
# Item
# Wine  4039.32

# %%
df['Area'].nunique()
# Out:
# 49

# %%
df_Area_Y2017=df[['Area','Y2017']]
df_Area_Y2017
# Out:
#            Area     Y2017
# 0       Algeria  41389.00
# 1       Algeria      0.00
# 2       Algeria   3341.00
# 3       Algeria     92.82
# 4       Algeria     80.19
# ...         ...       ...
# 60938  Zimbabwe     19.00
# 60939  Zimbabwe      1.33
# 60940  Zimbabwe      1.00
# 60941  Zimbabwe      0.04
# 60942  Zimbabwe      0.02
#
# [60943 rows x 2 columns]

# %%
df_Area_Y2017.groupby('Area').sum().idxmax()
# Out:
# Y2017    Nigeria
# dtype: object

# %%
df.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.loc( )

# %%
df.iloc( )

# %%
df.shape
# Out:
# (60943, 12)

# %%
MD_Y2014=df.isnull().sum().loc['Y2014']
MD_Y2014
# Out:
# 1589

# %%
Percent_MD_Y2014=round((MD_Y2014 * 100 / len(df)), 3)

print('The % of missing data in 2014 =', Percent_MD_Y2014,'%')
# Out:
# The % of missing data in 2014 = 2.607 %

# %%
df.corr()[['Element Code']].sort_values(by='Element Code', ascending=True)
# Out:
#               Element Code
# Item Code        -0.024683
# Area Code        -0.000209
# Y2016             0.023444
# Y2015             0.023889
# Y2017             0.024254
# Y2018             0.024279
# Y2014             0.024457
# Element Code      1.000000

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
x = y[1][1]
print(x)
# Out:
# 8

# %%
df.groupby('Element').sum().loc[['Stock Variation']]
# Out:
#                  Area Code  Item Code  Element Code     Y2014     Y2015  \
# Element
# Stock Variation     571566   11329527      21464704  58749.83  34910.99
#
#                     Y2016     Y2017     Y2018
# Element
# Stock Variation  33140.12  54316.91  20577.91

# %%
df.groupby('Element').sum().loc[['Processing'],['Y2017']]
# Out:
#                Y2017
# Element
# Processing  292836.0

# %%
df_Area_Y2017.groupby('Area').sum().sort_values(by='Y2017',ascending=True)
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-ce1543b3be47> in <module>
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df.loc(:)
